# %% [markdown]
# class Vettori:
#
#     def associativity(self,vettori):
#         True
#
#     def equipollenza(self,vettori):
#         if v1 == v2 except application point:
#             return True
#         if exists AB, C:
#             exists CD equipollente AB
#
# class Vettori Liberi(Vettori):
